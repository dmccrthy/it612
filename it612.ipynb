# %% [markdown]
# <a href="https://colab.research.google.com/github/dmccrthy/it612/blob/main/it612.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# // Task 1
# const addTax = (price, rate) => {
#   return price + (price * rate);
# }
#
# console.log(addTax(10, 0.05));
# console.log(addTax(250, 0.75));
#
# // Task 2
# const createBurner = (secret, limit) => {
#   return () => {
#     // Only returns the secret "limit" number of times
#     if (limit > 0) {
#       limit--;
#       return secret;
#     } else {
#       return "none";
#     }
#   }
# }
#
# // should return word twice then none.
# let burner = createBurner("word", 2);
# for (let i = 3; i > 0; i--) {
#   console.log(burner());;
# }
#
# // Task 3
# let object = { key: { nested: "value"} };
#
# console.log(`Stringify: ${JSON.stringify(object)}`);
# console.log(`Object: ${JSON.parse(JSON.stringify(object))}`);
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 10.5
# 437.5
# word
# word
# none
# Stringify: {"key":{"nested":"value"}}
# Object: [object Object]
